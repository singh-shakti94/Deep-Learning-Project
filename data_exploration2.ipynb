# %% [markdown]
# # Feature Exploration

# %%
train = pd.read_json("train.json")

def band_mean(band):
    band = np.array(band)
    return band.mean()


train['band_1_mean'] = train['band_1'].apply(band_mean)
train['band_2_mean'] = train['band_2'].apply(band_mean)


def band_median(band):
    band = np.array(band)
    return np.median(band)


train['band_1_median'] = train['band_1'].apply(band_median)
train['band_2_median'] = train['band_2'].apply(band_median)


def band_max(band):
    band = np.array(band)
    return band.max()


train['band_1_max'] = train['band_1'].apply(band_max)
train['band_2_max'] = train['band_2'].apply(band_max)


def band_min(band):
    band = np.array(band)
    return band.min()


train['band_1_min'] = train['band_1'].apply(band_min)
train['band_2_min'] = train['band_2'].apply(band_min)

# %%
sns.set(color_codes=True)


x1 = train['band_2_max'][train['is_iceberg'] == 1]
x2 = train['band_2_max'][train['is_iceberg'] == 0]
sns.distplot(x1, label='Iceberg')
sns.distplot(x2, label='Ship')

plt.xlabel('Maximum Pixel Intensity, Band 2 (dB)')
plt.ylabel('Density')
plt.title('Feature Engineering: Maximum Pixel Intensity, Band 2')
plt.legend()

plt.show()

# %%
x1 = train['band_1_max'][train['is_iceberg'] == 1]
x2 = train['band_1_max'][train['is_iceberg'] == 0]
sns.distplot(x1, label='Iceberg')
sns.distplot(x2, label='Ship')

plt.xlabel('Maximum Pixel Intensity, Band 1 (dB)')
plt.ylabel('Density')
plt.title('Feature Engineering: Maximum Pixel Intensity, Band 1')
plt.legend()

plt.show()

# %%
x1 = train['band_1_mean'][train['is_iceberg'] == 1]
x2 = train['band_1_mean'][train['is_iceberg'] == 0]
sns.distplot(x1, label='Iceberg')
sns.distplot(x2, label='Ship')

plt.xlabel('Mean Pixel Intensity, Band 1 (dB)')
plt.ylabel('Density')
plt.title('Feature Engineering: Mean Pixel Intensity, Band 1')
plt.legend()

plt.show()

# %%
x1 = train['band_2_mean'][train['is_iceberg'] == 1]
x2 = train['band_2_mean'][train['is_iceberg'] == 0]
sns.distplot(x1, label='Iceberg')
sns.distplot(x2, label='Ship')

plt.xlabel('Mean Pixel Intensity, Band 2 (dB)')
plt.ylabel('Density')
plt.title('Feature Engineering: Mean Pixel Intensity, Band 2')
plt.legend()

plt.show()

# %%
x1 = train['band_1_median'][train['is_iceberg'] == 1]
x2 = train['band_1_median'][train['is_iceberg'] == 0]
sns.distplot(x1, label='Iceberg')
sns.distplot(x2, label='Ship')

plt.xlabel('Median Pixel Intensity, Band 1 (dB)')
plt.ylabel('Density')
plt.title('Feature Engineering: Median Pixel Intensity, Band 1')
plt.legend()

plt.show()

# %%
x1 = train['band_2_median'][train['is_iceberg'] == 1]
x2 = train['band_2_median'][train['is_iceberg'] == 0]
sns.distplot(x1, label='Iceberg')
sns.distplot(x2, label='Ship')

plt.xlabel('Median Pixel Intensity, Band 2 (dB)')
plt.ylabel('Density')
plt.title('Feature Engineering: Median Pixel Intensity, Band 2')
plt.legend()

plt.show()

# %%
x1 = train['band_1_min'][train['is_iceberg'] == 1]
x2 = train['band_1_min'][train['is_iceberg'] == 0]
sns.distplot(x1, label='Iceberg')
sns.distplot(x2, label='Ship')

plt.xlabel('Minimum Pixel Intensity, Band 1 (dB)')
plt.ylabel('Density')
plt.title('Feature Engineering: Minimum Pixel Intensity, Band 1')
plt.legend()

plt.show()

# %%
x1 = train['band_2_min'][train['is_iceberg'] == 1]
x2 = train['band_2_min'][train['is_iceberg'] == 0]
sns.distplot(x1, label='Iceberg')
sns.distplot(x2, label='Ship')

plt.xlabel('Minimum Pixel Intensity, Band 2 (dB)')
plt.ylabel('Density')
plt.title('Feature Engineering: Minimum Pixel Intensity, Band 2')
plt.legend()

plt.show()
